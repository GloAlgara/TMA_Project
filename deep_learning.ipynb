# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import BaggingClassifier
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %% [markdown]
# # Inside the network

# %%
column_types = {'device_model': 'str'}
df_access = pd.read_csv('access_point.csv', dtype=column_types)
df_doorbell = pd.read_csv('doorbell.csv', dtype=column_types)
df_laptop_7400 = pd.read_csv('laptop_7400.csv', dtype=column_types)
df_laptop_e64 = pd.read_csv('laptop_e64.csv', dtype=column_types)
df_lightbulb = pd.read_csv('lightbulb.csv', dtype=column_types)
df_samsung_web = pd.read_csv('samsung_web.csv', dtype=column_types)
df_smartphone_4 = pd.read_csv('smartphone_4.csv', dtype=column_types)
df_smartphone_5 = pd.read_csv('smartphone_5.csv', dtype=column_types)
df_socket = pd.read_csv('socket.csv', dtype=column_types)
df_speaker = pd.read_csv('speaker.csv', dtype=column_types)
df_streamer = pd.read_csv('streamer.csv', dtype=column_types)
df_webcam = pd.read_csv('webcam.csv', dtype=column_types)

df_2 = pd.concat([df_samsung_web, df_access, df_doorbell, df_laptop_7400, df_laptop_e64, df_lightbulb, df_smartphone_4, df_smartphone_5, df_socket, df_speaker, df_streamer, df_webcam], ignore_index=True)

nocolumns = ['IPV4_SRC_ADDR', 'MAC', 'IPV4_DST_ADDR', 'IP', 'partition', 'category', 'type', 'date']

df = df_2.drop(nocolumns, axis=1)

X = df.drop(columns='device_model', axis=1)
Y = df['device_model']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

label_encoder = LabelEncoder()
Y_encoded = label_encoder.fit_transform(Y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y_encoded, test_size=0.2, random_state=0)

# Model architecture with dropout for regularization
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[EarlyStopping(patience=5)])

accuracy = model.evaluate(X_test, y_test)[1]
print('Neural Network Accuracy: {:.2f}%'.format(accuracy * 100))

predictions = model.predict(X_test)
predictions_class = np.argmax(predictions, axis=1)
predictions_labels = label_encoder.inverse_transform(predictions_class)
# Out:
# Epoch 1/50
# 15653/15653 [==============================] - 141s 6ms/step - loss: 0.5086 - accuracy: 0.8158 - val_loss: 0.3144 - val_accuracy: 0.8644
# Epoch 2/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.3393 - accuracy: 0.8611 - val_loss: 0.2890 - val_accuracy: 0.8703
# Epoch 3/50
# 15653/15653 [==============================] - 104s 7ms/step - loss: 0.3086 - accuracy: 0.8674 - val_loss: 0.2727 - val_accuracy: 0.8737
# Epoch 4/50
# 15653/15653 [==============================] - 100s 6ms/step - loss: 0.2945 - accuracy: 0.8704 - val_loss: 0.2570 - val_accuracy: 0.8807
# Epoch 5/50
# 15653/15653 [==============================] - 101s 6ms/step - loss: 0.2783 - accuracy: 0.8739 - val_loss: 0.2385 - val_accuracy: 0.8864
# Epoch 6/50
# 15653/15653 [==============================] - 98s 6ms/step - loss: 0.2624 - accuracy: 0.8799 - val_loss: 0.2255 - val_accuracy: 0.8917
# Epoch 7/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2530 - accuracy: 0.8841 - val_loss: 0.2185 - val_accuracy: 0.8926
# Epoch 8/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2452 - accuracy: 0.8871 - val_loss: 0.2139 - val_accuracy: 0.8957
# Epoch 9/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2390 - accuracy: 0.8893 - val_loss: 0.2097 - val_accuracy: 0.8980
# Epoch 10/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2351 - accuracy: 0.8921 - val_loss: 0.2059 - val_accuracy: 0.8994
# Epoch 11/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.2283 - accuracy: 0.8991 - val_loss: 0.1915 - val_accuracy: 0.9221
# Epoch 12/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2192 - accuracy: 0.9112 - val_loss: 0.1806 - val_accuracy: 0.9279
# Epoch 13/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2059 - accuracy: 0.9228 - val_loss: 0.1520 - val_accuracy: 0.9497
# Epoch 14/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.1912 - accuracy: 0.9339 - val_loss: 0.1441 - val_accuracy: 0.9531
# Epoch 15/50
# 15653/15653 [==============================] - 92s 6ms/step - loss: 0.1808 - accuracy: 0.9383 - val_loss: 0.1370 - val_accuracy: 0.9552
# Epoch 16/50
# 15653/15653 [==============================] - 97s 6ms/step - loss: 0.1766 - accuracy: 0.9399 - val_loss: 0.1357 - val_accuracy: 0.9558
# Epoch 17/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.1729 - accuracy: 0.9414 - val_loss: 0.1348 - val_accuracy: 0.9553
# Epoch 18/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.1709 - accuracy: 0.9422 - val_loss: 0.1350 - val_accuracy: 0.9552
# Epoch 19/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.1690 - accuracy: 0.9431 - val_loss: 0.1341 - val_accuracy: 0.9553
# Epoch 20/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.1682 - accuracy: 0.9439 - val_loss: 0.1307 - val_accuracy: 0.9580
# Epoch 21/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.1658 - accuracy: 0.9443 - val_loss: 0.1316 - val_accuracy: 0.9572
# Epoch 22/50
# 15653/15653 [==============================] - 89s 6ms/step - loss: 0.1648 - accuracy: 0.9449 - val_loss: 0.1295 - val_accuracy: 0.9573
# Epoch 23/50
# 15653/15653 [==============================] - 92s 6ms/step - loss: 0.1642 - accuracy: 0.9452 - val_loss: 0.1302 - val_accuracy: 0.9574
# Epoch 24/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.1617 - accuracy: 0.9459 - val_loss: 0.1307 - val_accuracy: 0.9569
# Epoch 25/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.1628 - accuracy: 0.9464 - val_loss: 0.1276 - val_accuracy: 0.9591
# Epoch 26/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.1601 - accuracy: 0.9468 - val_loss: 0.1354 - val_accuracy: 0.9543
# Epoch 27/50
# 15653/15653 [==============================] - 92s 6ms/step - loss: 0.1597 - accuracy: 0.9472 - val_loss: 0.1225 - val_accuracy: 0.9604
# Epoch 28/50
# 15653/15653 [==============================] - 89s 6ms/step - loss: 0.1590 - accuracy: 0.9476 - val_loss: 0.1246 - val_accuracy: 0.9590
# Epoch 29/50
# 15653/15653 [==============================] - 92s 6ms/step - loss: 0.1579 - accuracy: 0.9479 - val_loss: 0.1273 - val_accuracy: 0.9577
# Epoch 30/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.1583 - accuracy: 0.9482 - val_loss: 0.1245 - val_accuracy: 0.9588
# Epoch 31/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.1556 - accuracy: 0.9488 - val_loss: 0.1226 - val_accuracy: 0.9598
# Epoch 32/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.1550 - accuracy: 0.9491 - val_loss: 0.1261 - val_accuracy: 0.9578
# 4892/4892 [==============================] - 12s 2ms/step - loss: 0.1287 - accuracy: 0.9573
# Neural Network Accuracy: 95.73%
# 4892/4892 [==============================] - 11s 2ms/step

# %%
predictions_df = pd.DataFrame(predictions_labels, index=y_test, columns=['Predicted_Label'])

# Calculate metrics
accuracy_nn = accuracy_score(y_test, predictions_class)
precision_nn = precision_score(y_test, predictions_class, average='macro')
recall_nn = recall_score(y_test, predictions_class, average='macro')
f1_nn = f1_score(y_test, predictions_class, average='macro')

print('Neural Network Accuracy: {:.2f}%'.format(accuracy_nn * 100))
print('Neural Network Precision: {:.2f}%'.format(precision_nn*100))
print('Neural Network Recall: {:.2f}%'.format(recall_nn*100))
print('Neural Network F1 Score: {:.2f}%'.format(f1_nn*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Neural Network Accuracy: 95.73%
# Neural Network Precision: 84.20%
# Neural Network Recall: 80.22%
# Neural Network F1 Score: 81.42%

# %%
conf_matrix = confusion_matrix(y_test, predictions_class)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# # Outside the network

# %%
 column_types = {'device_model': 'str'}
df_access = pd.read_csv('access_point.csv', dtype=column_types)
df_doorbell = pd.read_csv('doorbell.csv', dtype=column_types)
df_laptop_7400 = pd.read_csv('laptop_7400.csv', dtype=column_types)
df_laptop_e64 = pd.read_csv('laptop_e64.csv', dtype=column_types)
df_lightbulb = pd.read_csv('lightbulb.csv', dtype=column_types)
df_samsung_web = pd.read_csv('samsung_web.csv', dtype=column_types)
df_smartphone_4 = pd.read_csv('smartphone_4.csv', dtype=column_types)
df_smartphone_5 = pd.read_csv('smartphone_5.csv', dtype=column_types)
df_socket = pd.read_csv('socket.csv', dtype=column_types)
df_speaker = pd.read_csv('speaker.csv', dtype=column_types)
df_streamer = pd.read_csv('streamer.csv', dtype=column_types)
df_webcam = pd.read_csv('webcam.csv', dtype=column_types)

df_2 = pd.concat([df_samsung_web, df_access, df_doorbell, df_laptop_7400, df_laptop_e64, df_lightbulb, df_smartphone_4, df_smartphone_5, df_socket, df_speaker, df_streamer, df_webcam], ignore_index=True)

nocolumns = ['IPV4_SRC_ADDR', 'MAC', 'IPV4_DST_ADDR', 'IP', 'partition', 'category', 'type', 'date', 'LAST_SWITCHED', 'FIRST_SWITCHED', 'SRC_TOS', 'SRC_AS', 'DST_AS']

df = df_2.drop(nocolumns, axis=1)

X = df.drop(columns='device_model', axis=1)
Y = df['device_model']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

label_encoder = LabelEncoder()
Y_encoded = label_encoder.fit_transform(Y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y_encoded, test_size=0.2, random_state=0)

# Model architecture with dropout for regularization
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[EarlyStopping(patience=5)])

accuracy = model.evaluate(X_test, y_test)[1]
print('Neural Network Accuracy: {:.2f}%'.format(accuracy * 100))

predictions = model.predict(X_test)
predictions_class = np.argmax(predictions, axis=1)
predictions_labels = label_encoder.inverse_transform(predictions_class)
# Out:
# Epoch 1/50
# 15653/15653 [==============================] - 129s 8ms/step - loss: 0.5067 - accuracy: 0.8177 - val_loss: 0.3260 - val_accuracy: 0.8581
# Epoch 2/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.3427 - accuracy: 0.8583 - val_loss: 0.2991 - val_accuracy: 0.8665
# Epoch 3/50
# 15653/15653 [==============================] - 99s 6ms/step - loss: 0.3204 - accuracy: 0.8637 - val_loss: 0.2881 - val_accuracy: 0.8722
# Epoch 4/50
# 15653/15653 [==============================] - 97s 6ms/step - loss: 0.3085 - accuracy: 0.8661 - val_loss: 0.2749 - val_accuracy: 0.8708
# Epoch 5/50
# 15653/15653 [==============================] - 99s 6ms/step - loss: 0.2922 - accuracy: 0.8688 - val_loss: 0.2570 - val_accuracy: 0.8836
# Epoch 6/50
# 15653/15653 [==============================] - 107s 7ms/step - loss: 0.2791 - accuracy: 0.8737 - val_loss: 0.2420 - val_accuracy: 0.8843
# Epoch 7/50
# 15653/15653 [==============================] - 97s 6ms/step - loss: 0.2701 - accuracy: 0.8784 - val_loss: 0.2335 - val_accuracy: 0.8877
# Epoch 8/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2594 - accuracy: 0.8818 - val_loss: 0.2286 - val_accuracy: 0.8918
# Epoch 9/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2532 - accuracy: 0.8849 - val_loss: 0.2241 - val_accuracy: 0.8946
# Epoch 10/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2492 - accuracy: 0.8866 - val_loss: 0.2200 - val_accuracy: 0.9112
# Epoch 11/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2454 - accuracy: 0.8884 - val_loss: 0.2175 - val_accuracy: 0.8987
# Epoch 12/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2448 - accuracy: 0.8896 - val_loss: 0.2158 - val_accuracy: 0.8985
# Epoch 13/50
# 15653/15653 [==============================] - 97s 6ms/step - loss: 0.2396 - accuracy: 0.8898 - val_loss: 0.2131 - val_accuracy: 0.8985
# Epoch 14/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2372 - accuracy: 0.8918 - val_loss: 0.2099 - val_accuracy: 0.9001
# Epoch 15/50
# 15653/15653 [==============================] - 92s 6ms/step - loss: 0.2339 - accuracy: 0.8922 - val_loss: 0.2088 - val_accuracy: 0.9000
# Epoch 16/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2327 - accuracy: 0.8930 - val_loss: 0.2061 - val_accuracy: 0.9009
# Epoch 17/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2309 - accuracy: 0.8938 - val_loss: 0.2055 - val_accuracy: 0.9010
# Epoch 18/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2289 - accuracy: 0.8942 - val_loss: 0.2040 - val_accuracy: 0.9017
# Epoch 19/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2290 - accuracy: 0.8946 - val_loss: 0.2028 - val_accuracy: 0.9019
# Epoch 20/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.2269 - accuracy: 0.8951 - val_loss: 0.2012 - val_accuracy: 0.9023
# Epoch 21/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2249 - accuracy: 0.8960 - val_loss: 0.2016 - val_accuracy: 0.9020
# Epoch 22/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.2252 - accuracy: 0.8965 - val_loss: 0.2002 - val_accuracy: 0.9024
# Epoch 23/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.2237 - accuracy: 0.8963 - val_loss: 0.2002 - val_accuracy: 0.9029
# Epoch 24/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2234 - accuracy: 0.8969 - val_loss: 0.2002 - val_accuracy: 0.9026
# Epoch 25/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.2221 - accuracy: 0.8965 - val_loss: 0.1993 - val_accuracy: 0.9060
# Epoch 26/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2212 - accuracy: 0.8974 - val_loss: 0.1992 - val_accuracy: 0.9024
# Epoch 27/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.2209 - accuracy: 0.8977 - val_loss: 0.1983 - val_accuracy: 0.9033
# Epoch 28/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2194 - accuracy: 0.8978 - val_loss: 0.1974 - val_accuracy: 0.9034
# Epoch 29/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.2221 - accuracy: 0.8979 - val_loss: 0.1975 - val_accuracy: 0.8987
# Epoch 30/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2189 - accuracy: 0.8984 - val_loss: 0.1986 - val_accuracy: 0.9029
# Epoch 31/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.2180 - accuracy: 0.8986 - val_loss: 0.1973 - val_accuracy: 0.9034
# Epoch 32/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.2175 - accuracy: 0.8985 - val_loss: 0.1965 - val_accuracy: 0.9036
# Epoch 33/50
# 15653/15653 [==============================] - 90s 6ms/step - loss: 0.2196 - accuracy: 0.8982 - val_loss: 0.1970 - val_accuracy: 0.9034
# Epoch 34/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2188 - accuracy: 0.8985 - val_loss: 0.1970 - val_accuracy: 0.9028
# Epoch 35/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2176 - accuracy: 0.8987 - val_loss: 0.1955 - val_accuracy: 0.9120
# Epoch 36/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2180 - accuracy: 0.8990 - val_loss: 0.1966 - val_accuracy: 0.9040
# Epoch 37/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2167 - accuracy: 0.8997 - val_loss: 0.1953 - val_accuracy: 0.9043
# Epoch 38/50
# 15653/15653 [==============================] - 94s 6ms/step - loss: 0.2165 - accuracy: 0.8991 - val_loss: 0.1955 - val_accuracy: 0.9041
# Epoch 39/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2155 - accuracy: 0.8994 - val_loss: 0.1951 - val_accuracy: 0.9041
# Epoch 40/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2155 - accuracy: 0.8992 - val_loss: 0.1946 - val_accuracy: 0.9043
# Epoch 41/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2156 - accuracy: 0.8994 - val_loss: 0.1950 - val_accuracy: 0.9061
# Epoch 42/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2146 - accuracy: 0.9001 - val_loss: 0.1946 - val_accuracy: 0.9069
# Epoch 43/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2149 - accuracy: 0.8998 - val_loss: 0.1945 - val_accuracy: 0.9050
# Epoch 44/50
# 15653/15653 [==============================] - 92s 6ms/step - loss: 0.2177 - accuracy: 0.9004 - val_loss: 0.1934 - val_accuracy: 0.9040
# Epoch 45/50
# 15653/15653 [==============================] - 95s 6ms/step - loss: 0.2151 - accuracy: 0.9002 - val_loss: 0.1945 - val_accuracy: 0.9026
# Epoch 46/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2154 - accuracy: 0.9001 - val_loss: 0.1933 - val_accuracy: 0.9128
# Epoch 47/50
# 15653/15653 [==============================] - 96s 6ms/step - loss: 0.2150 - accuracy: 0.8999 - val_loss: 0.1937 - val_accuracy: 0.9189
# Epoch 48/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2147 - accuracy: 0.9001 - val_loss: 0.1940 - val_accuracy: 0.9044
# Epoch 49/50
# 15653/15653 [==============================] - 93s 6ms/step - loss: 0.2140 - accuracy: 0.9004 - val_loss: 0.1927 - val_accuracy: 0.9073
# Epoch 50/50
# 15653/15653 [==============================] - 91s 6ms/step - loss: 0.2140 - accuracy: 0.9007 - val_loss: 0.1941 - val_accuracy: 0.9032
# 4892/4892 [==============================] - 12s 2ms/step - loss: 0.1953 - accuracy: 0.9040
# Neural Network Accuracy: 90.40%
# 4892/4892 [==============================] - 11s 2ms/step

# %%
predictions_df = pd.DataFrame(predictions_labels, index=y_test, columns=['Predicted_Label'])

# Calculate metrics
accuracy_nn = accuracy_score(y_test, predictions_class)
precision_nn = precision_score(y_test, predictions_class, average='macro')
recall_nn = recall_score(y_test, predictions_class, average='macro')
f1_nn = f1_score(y_test, predictions_class, average='macro')

print('Neural Network Accuracy: {:.2f}%'.format(accuracy_nn * 100))
print('Neural Network Precision: {:.2f}%'.format(precision_nn*100))
print('Neural Network Recall: {:.2f}%'.format(recall_nn*100))
print('Neural Network F1 Score: {:.2f}%'.format(f1_nn*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Neural Network Accuracy: 90.40%
# Neural Network Precision: 79.48%
# Neural Network Recall: 74.39%
# Neural Network F1 Score: 75.00%

# %%
conf_matrix = confusion_matrix(y_test, predictions_class)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
